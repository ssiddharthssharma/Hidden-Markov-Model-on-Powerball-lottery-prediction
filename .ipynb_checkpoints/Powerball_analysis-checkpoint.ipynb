# %%
import numpy as np
import pandas as pd
from hmmlearn import hmm
import matplotlib.pyplot as plt
from pandas.tools.plotting import scatter_matrix

# %%
pb_data=pd.read_csv('data.csv')
print(pb_data.head())
# Out:
#      DrawDate  WB1  WB2  WB3  WB4  WB5  PB    PP
# 0  03/15/2017   30   16   41   48   53  16   3.0
# 1  03/11/2017   57   41   50   26    1  11   2.0
# 2  03/08/2017   42   23   59   46   33   4   2.0
# 3  03/04/2017    2   22   63   19   18  19   3.0
# 4  03/01/2017   16   10   52   40   55  17  10.0

# %%
pb_data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10140D30>,
# ...
#       dtype=object)

# %%
#pb_data['WB1'].value_counts()[:69].plot(kind='barh'w1d = pb_data['WB1'].value_counts()[:69].plot(kind='barh', figsize=(10,12)))
print(pb_data.shape)

# %%
w1d = pb_data['WB1'].value_counts()[:69].plot(kind='barh', figsize=(10,12))
plt.savefig('wb1.png', bbox_inches='tight')
w2d = pb_data['WB2'].value_counts()[:69].plot(kind='barh', figsize=(10,12))
plt.savefig('wb2.png', bbox_inches='tight')
w3d = pb_data['WB3'].value_counts()[:69].plot(kind='barh', figsize=(10,12))
plt.savefig('wb3.png', bbox_inches='tight')
w4d = pb_data['WB4'].value_counts()[:69].plot(kind='barh', figsize=(10,12))
plt.savefig('wb4.png', bbox_inches='tight')
w5d = pb_data['WB5'].value_counts()[:69].plot(kind='barh', figsize=(10,12))
plt.savefig('wb5.png', bbox_inches='tight')
pbd = pb_data['PB'].value_counts()[:26].plot(kind='barh', figsize=(10,12))
plt.savefig('pb.png', bbox_inches='tight')

# %%
#model = hmm.GaussianHMM(n_components=69, covariance_type="full")
print(pb_data.shape)
xa=np.arange(1,2022)

# %%
scatter_matrix(pb_data, alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# c:\python27\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   """Entry point for launching an IPython kernel.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10489BB0>,
# ...
#       dtype=object)

# %%
start=np.full((1,69),0.01449275362)
transition=np.full((69,69),0.01449275362)
emmision= np.identity(69)
model = hmm.GaussianHMM(n_components=69, covariance_type="full")
model.startprob_ = start
model.transmat_ = transition
model.means_ = means
model.covars_ = covars
model.predict(X)
